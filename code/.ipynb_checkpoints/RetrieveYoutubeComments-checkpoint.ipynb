# %%
import google.oauth2.credentials
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow
import sys
import json
import pandas as pd

# %%
DEVELOPER_KEY = "AIzaSyBWYDtwKfGqoycYh8C_x4LCEEJEYyC0JA0" 
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# %%
# Call the API's commentThreads.list method to list the existing comments.
def get_comments(youtube, video_id, channel_id):
  results = youtube.commentThreads().list(
    part= "replies",# "snippet",
    videoId=video_id,
    channelId=channel_id,
    textFormat="plainText"
  ).execute()

  for item in results["items"]:
    comment = item["snippet"]["topLevelComment"]
    author = comment["snippet"]["authorDisplayName"]
    text = comment["snippet"]["textDisplay"]
    print("Comment by %s: %s" % (author, text))

  return results["items"]

# %%
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
    developerKey=DEVELOPER_KEY)
# get_comments(youtube,'ptZ2mwUaJxg',None)

# %% [markdown]
# |VideoId|CommitId|likes|reply_number|comments|level|
# |-------|--------|-----|------------|--------|-----|
# |cGUr0QXNCmc||||||

# %%
results = {}
youtube_data = pd.DataFrame(columns=["VideoID", "CommentID","Likes","RepliesCount","CommentText","ParentCommentID"])
results['nextPageToken'] = None

# %%
results = youtube.commentThreads().list(
    part="snippet",# "snippet",
    videoId='cGUr0QXNCmc',
#     allThreadsRelatedToChannelId= 'UCQatgKoA7lylp_UzvsLCgcw',
#     channelId='UCvQfJ9-5TrIH2lErmUsjQ4Q',
    textFormat="plainText",
    maxResults = 10,
    order = 'relevance',
    pageToken =results['nextPageToken'] # Use this to go through a loop
  ).execute()

# %%
video_id = 'g4q3PtUNOcU'
idx = 1
results = {}
results['nextPageToken'] = None
youtube_data = pd.DataFrame(columns=["VideoID", "CommentID","Likes","RepliesCount","CommentText","ParentCommentID"])

while True:
    try:
        results = get_comment(video_id,2,results['nextPageToken'])
        for item in results["items"]:
            comment = item["snippet"]["topLevelComment"]
            commentid = item['id']
            text = comment["snippet"]["textDisplay"]
            like_count = comment['snippet']['likeCount']
            reply_count= item['snippet']['totalReplyCount']
            youtube_data = youtube_data.append({
             "VideoID":video_id, 
             "CommentID":commentid,
             "Likes":like_count,
             "RepliesCount":reply_count,
             "CommentText":text,
             "ParentCommentID":None
              }, ignore_index=True)
#             print("%d. Comment by %s(parent id %s) # %d: %s " % (idx, author, commentid,like_count, text))
            if reply_count >0:
                replies = youtube.comments().list(part='snippet',parentId=commentid,maxResults=100).execute()
                for reply in replies["items"]:
                    commentid_reply = reply['id']
                    text = reply["snippet"]["textOriginal"]
                    like_count = reply['snippet']['likeCount']
#                     print("%d. Comment by %s(parent id %s) # %d: %s " % (idx, author, commentid_reply,like_count, text))
                    youtube_data = youtube_data.append({
                     "VideoID":video_id, 
                     "CommentID":commentid_reply,
                     "Likes":like_count,
                     "RepliesCount":0,
                     "CommentText":text,
                     "ParentCommentID":commentid
                      }, ignore_index=True)
                    idx +=1
            idx +=1
    
    except:
        print("No more pages")
        break
# Out:
# hi
# {'snippet': {'isPublic': True, 'totalReplyCount': 0, 'canReply': True, 'topLevelComment': {'snippet': {'textOriginal': '我也发现到了 每次都逗紫宁😄', 'authorDisplayName': 'ng cheng', 'updatedAt': '2018-06-05T18:43:35.000Z', 'authorChannelId': {'value': 'UC7MwehU0CnfxE9b0JYy4Iww'}, 'authorProfileImageUrl': 'https://yt3.ggpht.com/-90e6W6R8od8/AAAAAAAAAAI/AAAAAAAAAAA/rGK_0gky0jk/s28-c-k-no-mo-rj-c0xffffff/photo.jpg', 'canRate': True, 'textDisplay': '我也发现到了 每次都逗紫宁😄', 'authorChannelUrl': 'http://www.youtube.com/channel/UC7MwehU0CnfxE9b0JYy4Iww', 'likeCount': 22, 'viewerRating': 'none', 'publishedAt': '2018-06-05T18:43:35.000Z', 'videoId': 'g4q3PtUNOcU'}, 'id': 'UgySr97DViVpwwJe9fB4AaABAg', 'kind': 'youtube#comment', 'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/XI2zFWIxSfjMkRprx8I1fG5GgQA"'}, 'videoId': 'g4q3PtUNOcU'}, 'id': 'UgySr97DViVpwwJe9fB4AaABAg', 'kind': 'youtube#commentThread', 'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/59JZwDrlc2fs1l6jgU2HTwRUz0s"'}
# ...

# %%
youtube_data
# Out:
#         VideoID                                          CommentID  Likes  \
# 0   g4q3PtUNOcU                         UgySr97DViVpwwJe9fB4AaABAg   22.0
# 1   g4q3PtUNOcU                         UgxfH-39YFD45qNk2iJ4AaABAg    6.0
# 2   g4q3PtUNOcU  UgxfH-39YFD45qNk2iJ4AaABAg.8h89EehcDCD8h8eDryfwG9    0.0
# 3   g4q3PtUNOcU  UgxfH-39YFD45qNk2iJ4AaABAg.8h89EehcDCD8h8eCqiv2l3    0.0
# 4   g4q3PtUNOcU  UgxfH-39YFD45qNk2iJ4AaABAg.8h89EehcDCD8h8VnqB-TDv    1.0
# 5   g4q3PtUNOcU  UgxfH-39YFD45qNk2iJ4AaABAg.8h89EehcDCD8h8NF097f9-    3.0
# 6   g4q3PtUNOcU  UgxfH-39YFD45qNk2iJ4AaABAg.8h89EehcDCD8h8KlEJaruw    0.0
# 7   g4q3PtUNOcU  UgxfH-39YFD45qNk2iJ4AaABAg.8h89EehcDCD8h8Is-t4R4Y    0.0
# 8   g4q3PtUNOcU                         UgwmIeR_FIaeXDE7gnF4AaABAg    7.0
# 9   g4q3PtUNOcU  UgwmIeR_FIaeXDE7gnF4AaABAg.8h87DyHeMmv8h8WGxRkHzB    0.0
# 10  g4q3PtUNOcU  UgwmIeR_FIaeXDE7gnF4AaABAg.8h87DyHeMmv8h8W3wHTkHY    1.0
# 11  g4q3PtUNOcU  UgwmIeR_FIaeXDE7gnF4AaABAg.8h87DyHeMmv8h8NK-7U-Ih    1.0
# ...

# %%
results['nextPageToken'] = None
def get_comment(video_id,max_records,next_token):
    results = youtube.commentThreads().list(
        part="snippet",# "snippet",
        videoId=video_id,
        textFormat="plainText",
        maxResults = max_records,
        order = 'relevance',
        pageToken = next_token # Use this to go through a loop
      ).execute()
    return results

# %%
results =
results
# Out:
# {'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/D2wBHF8o-DOcnYYMaO0sqjO-IR8"',
#  'items': [{'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/R8Rw9C1GLLkYa7v3ZAcrhJjuQmI"',
#    'id': 'UgySr97DViVpwwJe9fB4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/WqDMXFE7JrQtT2LJk3eUYuYnRHk"',
#      'id': 'UgySr97DViVpwwJe9fB4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UC7MwehU0CnfxE9b0JYy4Iww'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC7MwehU0CnfxE9b0JYy4Iww',
#       'authorDisplayName': 'ng cheng',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-90e6W6R8od8/AAAAAAAAAAI/AAAAAAAAAAA/rGK_0gky0jk/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 19,
#       'publishedAt': '2018-06-05T18:43:35.000Z',
#       'textDisplay': '我也发现到了 每次都逗紫宁😄',
#       'textOriginal': '我也发现到了 每次都逗紫宁😄',
# ...

# %%
results = get_comment('g4q3PtUNOcU',5,results['nextPageToken'] )
results
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-0f3d68bf1f79> in <module>()
# ----> 1 results = get_comment('g4q3PtUNOcU',5,results['nextPageToken'] )
#       2 results
#
# KeyError: 'nextPageToken'

# %%
results
# Out:
# {'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/kP-vLoLmXYpU82zjI34sjJTwcuM"',
#  'items': [{'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/R8Rw9C1GLLkYa7v3ZAcrhJjuQmI"',
#    'id': 'UgySr97DViVpwwJe9fB4AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/WqDMXFE7JrQtT2LJk3eUYuYnRHk"',
#      'id': 'UgySr97DViVpwwJe9fB4AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UC7MwehU0CnfxE9b0JYy4Iww'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC7MwehU0CnfxE9b0JYy4Iww',
#       'authorDisplayName': 'ng cheng',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-90e6W6R8od8/AAAAAAAAAAI/AAAAAAAAAAA/rGK_0gky0jk/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 19,
#       'publishedAt': '2018-06-05T18:43:35.000Z',
#       'textDisplay': '我也发现到了 每次都逗紫宁😄',
#       'textOriginal': '我也发现到了 每次都逗紫宁😄',
# ...

# %%
idx=0
for reply in replies["items"]:
#     commentID= replies[items][id])
    commentid = reply['id']
    author = reply["snippet"]["authorDisplayName"]
    text = reply["snippet"]["textOriginal"]
    like_count = reply['snippet']['likeCount']
    print("%d. Comment by %s(parent id %s) # %d: %s " % (idx, author, commentid,like_count, text))
    idx +=1

#     reply_count= item['snippet']['totalReplyCount']
# Out:
# 0. Comment by Chin KimberLAY(parent id Ugzpo61SJCdIhikWs_Z4AaABAg.8fWandQg8R78gkMK_UefDG) # 0: Tao said he likes the one who like him too ❤️
# 1. Comment by Yan yan 'ᄉ'(parent id Ugzpo61SJCdIhikWs_Z4AaABAg.8fWandQg8R78gQxLlhNnXd) # 0: 😭
# 2. Comment by 李宇敏(parent id Ugzpo61SJCdIhikWs_Z4AaABAg.8fWandQg8R78fcryarhEKb) # 4: The concert is EXO PLANET#1 in Taipei. I was at this concert😭 so sad😢
# 3. Comment by EXO- L(parent id Ugzpo61SJCdIhikWs_Z4AaABAg.8fWandQg8R78fc9FPf8VEG) # 3: OT12
# 4. Comment by 樂禕(parent id Ugzpo61SJCdIhikWs_Z4AaABAg.8fWandQg8R78f_gJvUishj) # 2: 😭😭😭😭
# 5. Comment by 張珈瑜(parent id Ugzpo61SJCdIhikWs_Z4AaABAg.8fWandQg8R78fY5z0VlLx3) # 2: Yarlet Lopez 😭

# %%
replies["items"][0]
# Out:
# {'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/g1NeBm_D_HVIIKOEtF-_U-3HDuA"',
#  'id': 'Ugzpo61SJCdIhikWs_Z4AaABAg.8fWandQg8R78gkMK_UefDG',
#  'kind': 'youtube#comment',
#  'snippet': {'authorChannelId': {'value': 'UCmckpc5Oufg5vM82-w6tScg'},
#   'authorChannelUrl': 'http://www.youtube.com/channel/UCmckpc5Oufg5vM82-w6tScg',
#   'authorDisplayName': 'Chin KimberLAY',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/-u0yVWAcbWXo/AAAAAAAAAAI/AAAAAAAAAAA/CtMFEvwlcVw/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#   'canRate': True,
#   'likeCount': 0,
#   'parentId': 'Ugzpo61SJCdIhikWs_Z4AaABAg',
#   'publishedAt': '2018-05-27T11:18:01.000Z',
#   'textDisplay': 'Tao said he likes the one who like him too ❤️',
#   'textOriginal': 'Tao said he likes the one who like him too ❤️',
#   'updatedAt': '2018-05-27T11:18:01.000Z',
#   'viewerRating': 'none'}}

# %%
replies = youtube.comments().list(
    part='snippet',
    parentId='Ugzpo61SJCdIhikWs_Z4AaABAg').execute()
replies
# Out:
# {'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/3WTY2-MlqnKcOwetdn4s4GjisFI"',
#  'items': [{'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/g1NeBm_D_HVIIKOEtF-_U-3HDuA"',
#    'id': 'Ugzpo61SJCdIhikWs_Z4AaABAg.8fWandQg8R78gkMK_UefDG',
#    'kind': 'youtube#comment',
#    'snippet': {'authorChannelId': {'value': 'UCmckpc5Oufg5vM82-w6tScg'},
#     'authorChannelUrl': 'http://www.youtube.com/channel/UCmckpc5Oufg5vM82-w6tScg',
#     'authorDisplayName': 'Chin KimberLAY',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/-u0yVWAcbWXo/AAAAAAAAAAI/AAAAAAAAAAA/CtMFEvwlcVw/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#     'canRate': True,
#     'likeCount': 0,
#     'parentId': 'Ugzpo61SJCdIhikWs_Z4AaABAg',
#     'publishedAt': '2018-05-27T11:18:01.000Z',
#     'textDisplay': 'Tao said he likes the one who like him too ❤️',
#     'textOriginal': 'Tao said he likes the one who like him too ❤️',
#     'updatedAt': '2018-05-27T11:18:01.000Z',
#     'viewerRating': 'none'}},
# ...

# %%
replies = youtube.comments().list(
    part='snippet',
    parentId='UgxwxATfPlRw0WYiQI14AaABAg').execute()
print(replies)
