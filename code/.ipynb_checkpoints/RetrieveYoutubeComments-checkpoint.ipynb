# %%
import sys
import json

sys.path.append("~/Documents/youtube_tutorial/")

# %%
import google.oauth2.credentials

from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow

# %%
# from apiclient.discovery import build
# from apiclient.errors import HttpError
# from oauth2client.tools import argparser

DEVELOPER_KEY = "AIzaSyBWYDtwKfGqoycYh8C_x4LCEEJEYyC0JA0" 
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# %%
def youtube_search(q, max_results=50,order="relevance", token=None, location=None, location_radius=None):

  youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
    developerKey=DEVELOPER_KEY)

  search_response = youtube.search().list(
    q=q,
    type="video",
    pageToken=token,
    order = order,
    part="id,snippet",
    maxResults=max_results,
    location=location,
    locationRadius=location_radius

  ).execute()



  videos = []

  for search_result in search_response.get("items", []):
    if search_result["id"]["kind"] == "youtube#video":
      videos.append(search_result)
  try:
      nexttok = search_response["nextPageToken"]
      return(nexttok, videos)
  except Exception as e:
      nexttok = "last_page"
      return(nexttok, videos)


def geo_query(video_id):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)

    video_response = youtube.videos().list(
        id=video_id,
        part='snippet, recordingDetails, statistics'

    ).execute()

    return video_response

# %%
test = youtube_search("spinners")
test
# Out:
# ('CDIQAA',
#  [{'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/5t6PKqgJg2S9pxdySmvPNlHjfhI"',
#    'id': {'kind': 'youtube#video', 'videoId': 'ojCikI9npJQ'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCyAaxR2630hLkvAWd-9uzgA',
#     'channelTitle': 'BakNDaDay',
#     'description': 'Spinners ©1973 Atlantic.',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2011-10-25T10:25:18.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/ojCikI9npJQ/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/ojCikI9npJQ/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/ojCikI9npJQ/mqdefault.jpg',
#       'width': 320}},
#     'title': "The Spinners - I'll Be Around"}},
#   {'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/EjASI_cp_Lv6biUoE_XvEomwNsE"',
#    'id': {'kind': 'youtube#video', 'videoId': 'Em_6THb7OdE'},
# ...

# %%
# Call the API's commentThreads.list method to list the existing comments.
def get_comments(youtube, video_id, channel_id):
  results = youtube.commentThreads().list(
    part= "replies",# "snippet",
    videoId=video_id,
    channelId=channel_id,
    textFormat="plainText"
  ).execute()

  for item in results["items"]:
    comment = item["snippet"]["topLevelComment"]
    author = comment["snippet"]["authorDisplayName"]
    text = comment["snippet"]["textDisplay"]
    print("Comment by %s: %s" % (author, text))

  return results["items"]

# %%
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
    developerKey=DEVELOPER_KEY)
get_comments(youtube,'ptZ2mwUaJxg',None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-738f947d038e> in <module>()
#       1 youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
#       2     developerKey=DEVELOPER_KEY)
# ----> 3 get_comments(youtube,'ptZ2mwUaJxg',None)
#
# <ipython-input-21-beb38bf04bbe> in get_comments(youtube, video_id, channel_id)
#       9
#      10   for item in results["items"]:
# ---> 11     comment = item["replies"]["topLevelComment"]
#      12     author = comment["replies"]["authorDisplayName"]
#      13     text = comment["replies"]["textDisplay"]
#
# KeyError: 'replies'

# %%
results = youtube.commentThreads().list(
    part="snippet,replies",# "snippet",
    videoId='oA0nMWhn9ns',
#     allThreadsRelatedToChannelId= 'UCQatgKoA7lylp_UzvsLCgcw',
#     channelId='UCvQfJ9-5TrIH2lErmUsjQ4Q',
    textFormat="plainText",
    maxResults = 100,
    order = 'relevance',
    pageToken =results['nextPageToken']
  ).execute()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-9637d1102c9d> in <module>()
#       7     maxResults = 100,
#       8     order = 'relevance',
# ----> 9     pageToken =results['nextPageToken']
#      10   ).execute()
#
# KeyError: 'nextPageToken'

# %% [markdown]
# |VideoId|CommitId|likes|reply_number|comments|level|
# |-------|--------|-----|------------|--------|-----|
# |cGUr0QXNCmc||||||

# %%
results
# Out:
# {'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/axF8KjfADcFdh2lGrOkCd7XfhjE"',
#  'items': [{'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/5NNtIRouTl2MS3F0BHshIovUAWo"',
#    'id': 'UgzpX6N_9sgyFO7Aop14AaABAg',
#    'kind': 'youtube#commentThread',
#    'snippet': {'canReply': True,
#     'isPublic': True,
#     'topLevelComment': {'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/7LV_FTCC5T4iXzAnGGWbWdDZlX8"',
#      'id': 'UgzpX6N_9sgyFO7Aop14AaABAg',
#      'kind': 'youtube#comment',
#      'snippet': {'authorChannelId': {'value': 'UCcxrf6rtAxZWUQU6ZRXLvIw'},
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCcxrf6rtAxZWUQU6ZRXLvIw',
#       'authorDisplayName': '邱東展',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-mEHkizwlW64/AAAAAAAAAAI/AAAAAAAAAAA/g-UXe9SzqgY/s28-c-k-no-mo-rj-c0xffffff/photo.jpg',
#       'canRate': True,
#       'likeCount': 0,
#       'publishedAt': '2018-06-06T03:02:04.000Z',
#       'textDisplay': '實至名歸的A班',
#       'textOriginal': '實至名歸的A班',
# ...

# %%
results['nextPageToken']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-9368a8fc0aab> in <module>()
# ----> 1 results['nextPageToken']
#
# KeyError: 'nextPageToken'

# %%
results['items'][0]['replies']['comments'][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-103-e23f24730a57> in <module>()
# ----> 1 results['items'][0]['replies']['comments'][1]
#
# IndexError: list index out of range

# %%
replies = results['items'][1]['replies']['comments']
for reply in replies:
    print(reply['snippet']['textOriginal'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-c29ef04691c5> in <module>()
# ----> 1 replies = results['items'][1]['replies']['comments']
#       2 for reply in replies:
#       3     print(reply['snippet']['textOriginal'])
#
# KeyError: 'replies'

# %%
idx = 1
for item in results["items"]:
    print(item,"\n")
#     replies = item['replies']['comments']
#     test = item['replies']
    comment = item["snippet"]["topLevelComment"]
    author = comment["snippet"]["authorDisplayName"]
    text = comment["snippet"]["textDisplay"]
    likecount = comment['snippet']['likeCount']
    parentid = item['id']
#     replies = item['replies']['comments']
#     for reply in replies:
#         reply_text = reply["snippet"]['textOriginal']    
    print("%d. Comment by %s(parent id %s) # %d: %s " % (idx, author, parentid,likecount, text))
    idx +=1
# Out:
# {'replies': {'comments': [{'kind': 'youtube#comment', 'snippet': {'likeCount': 0, 'publishedAt': '2018-06-05T12:59:29.000Z', 'viewerRating': 'none', 'textDisplay': 'Jin flying kiss makes my day ARMYBLINK 哈哈😂😂都是他們的粉絲😁😁', 'updatedAt': '2018-06-05T12:59:29.000Z', 'canRate': True, 'authorChannelId': {'value': 'UCvQfJ9-5TrIH2lErmUsjQ4Q'}, 'textOriginal': 'Jin flying kiss makes my day ARMYBLINK 哈哈😂😂都是他們的粉絲😁😁', 'parentId': 'UgxB1zy8AkazaTCoHUl4AaABAg', 'authorProfileImageUrl': 'https://yt3.ggpht.com/-PvmUnUSZ6Hg/AAAAAAAAAAI/AAAAAAAAAAA/sD72mEm6t3I/s28-c-k-no-mo-rj-c0xffffff/photo.jpg', 'authorDisplayName': '尤長靖是我們家小吃貨😂😂', 'authorChannelUrl': 'http://www.youtube.com/channel/UCvQfJ9-5TrIH2lErmUsjQ4Q', 'videoId': 'oA0nMWhn9ns'}, 'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/9GNzw1IZM7Av4-FmB5K6sozL4Yg"', 'id': 'UgxB1zy8AkazaTCoHUl4AaABAg.8h3iwjgO8x78h6i5bExq6t'}, {'kind': 'youtube#comment', 'snippet': {'likeCount': 1, 'publishedAt': '2018-06-05T12:53:42.000Z', 'viewerRating': 'none', 'textDisplay': '尤
# ...

# %%
replies = youtube.comments().list(
    part='snippet',
    parentId='UgxwxATfPlRw0WYiQI14AaABAg').execute()
print(replies)
# Out:
# {'kind': 'youtube#commentListResponse', 'pageInfo': {'resultsPerPage': 20}, 'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/zO4ifHtNomODRk7pm_9kPg0Vc4I"', 'items': []}

# %%
replies = youtube.comments().list(
    part='snippet',
    parentId='UgxwxATfPlRw0WYiQI14AaABAg').execute()
print(replies)
# Out:
# {'kind': 'youtube#commentListResponse', 'pageInfo': {'resultsPerPage': 20}, 'etag': '"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/zO4ifHtNomODRk7pm_9kPg0Vc4I"', 'items': []}
